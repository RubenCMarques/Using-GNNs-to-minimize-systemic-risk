# %% [markdown]
# # Data Exploration
#
# Explore the AI4Risk interbank network dataset (2016 Q1 - 2023 Q4).

# %%
import os
import sys
def find_project_root(start=None):
    start = Path(start or Path.cwd()).resolve()
    for path in [start, *start.parents]:
        if (path / 'src').exists() and (path / 'requirements.txt').exists():
            return path
    raise FileNotFoundError('Project root not found.')


PROJECT_ROOT = find_project_root()
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pyarrow

from src.data import load_data
from src.models import (
    degree_centrality,
    betweenness_centrality,
    closeness_centrality,
    eigenvector_centrality,
    weighted_degree,
    debtrank,
    pagerank_centrality,
)

from pathlib import Path

PROJECT_ROOT = find_project_root()
OUT_FEATURES = PROJECT_ROOT / "src" / "data" / "classical_features"
OUT_FEATURES.mkdir(parents=True, exist_ok=True)

OUT_FEATURES
# Out:
# WindowsPath('C:/Users/ruben/Desktop/Universidade/Nova IMS/Tese/Thesis/src/data/classical_features')

# %%
# Load all 32 quarters into individual DataFrames
rows = []

for year in range(2016, 2024):
    for q in range(1, 5):
        e, n = load_data(year, q)
        globals()[f"edges_{year}_Q{q}"] = e
        globals()[f"nodes_{year}_Q{q}"] = n
        rows.append({
            "year": year,
            "quarter": q,
            "period": f"{year} Q{q}",
            "n_banks": len(n),
            "n_edges": len(e),
        })
# Out:
# Loaded 2016 Q1: 4548 banks, 11631 edges
# Loaded 2016 Q2: 4548 banks, 11632 edges
# Loaded 2016 Q3: 4548 banks, 11937 edges
# Loaded 2016 Q4: 4548 banks, 11938 edges
# Loaded 2017 Q1: 4548 banks, 11939 edges
# Loaded 2017 Q2: 4548 banks, 11940 edges
# Loaded 2017 Q3: 4548 banks, 11941 edges
# Loaded 2017 Q4: 4548 banks, 11981 edges
# Loaded 2018 Q1: 4548 banks, 12416 edges
# Loaded 2018 Q2: 4548 banks, 12417 edges
# Loaded 2018 Q3: 4548 banks, 12418 edges
# Loaded 2018 Q4: 4548 banks, 12419 edges
# Loaded 2019 Q1: 4548 banks, 12420 edges
# Loaded 2019 Q2: 4548 banks, 12421 edges
# Loaded 2019 Q3: 4548 banks, 12422 edges
# Loaded 2019 Q4: 4548 banks, 12423 edges
# Loaded 2020 Q1: 4548 banks, 12424 edges
# Loaded 2020 Q2: 4548 banks, 12451 edges
# Loaded 2020 Q3: 4548 banks, 12452 edges
# Loaded 2020 Q4: 4548 banks, 12453 edges
# Loaded 2021 Q1: 4548 banks, 12454 edges
# Loaded 2021 Q2: 4548 banks, 12455 edges
# Loaded 2021 Q3: 4548 banks, 12456 edges
# Loaded 2021 Q4: 4548 banks, 12457 edges
# Loaded 2022 Q1: 4548 banks, 12458 edges
# Loaded 2022 Q2: 4548 banks, 12459 edges
# Loaded 2022 Q3: 4548 banks, 12460 edges
# Loaded 2022 Q4: 4548 banks, 12461 edges
# Loaded 2023 Q1: 4548 banks, 12462 edges
# Loaded 2023 Q2: 4548 banks, 12463 edges
# Loaded 2023 Q3: 4548 banks, 12464 edges
# Loaded 2023 Q4: 4548 banks, 12465 edges

# %%
# Quick look at the first and last quarters
print("=== 2016 Q1 Edges ===")
display(edges_2016_Q1.head())

print("\n=== 2016 Q1 Nodes ===")
display(nodes_2016_Q1.head())

print("\n=== 2023 Q4 Edges ===")
display(edges_2023_Q4.head())

print("\n=== 2023 Q4 Nodes ===")
display(nodes_2023_Q4.head())
# Out:
# === 2016 Q1 Edges ===
#    Sourceid  Targetid  Weights
# 0         0         1   4440.0
# 1         0         2   3809.0
# 2         0         3  16011.0
# 3         0         4  16674.0
# 4         0         5   2779.0
# === 2016 Q1 Nodes ===
#    index  Total_assets  Total_liabilities        Equity  Liquid_assets  \
# 0      0  2.015718e+09       1.817839e+09  1.978790e+08    995459000.0
# 1      1  1.653947e+09       1.445797e+09  2.081500e+08    520240000.0
# 2      2  1.342643e+09       1.194543e+09  1.481000e+08    584455000.0
# 3      3  1.667785e+09       1.513099e+09  1.546860e+08    555658000.0
# 4      4  8.335113e+08       7.826065e+08  5.090483e+07    313991467.7
#
#    Deposits_and_short-term_funding  Long-term_funding   Net_income  \
# 0                     1.532137e+09       9.085800e+07  4197000.000
# 1                     1.363841e+09       2.511900e+07  3712000.000
# 2                     1.009545e+09       6.186300e+07  2879000.000
# 3                     1.334370e+09       1.225960e+08  4735000.000
# 4                     5.811292e+08       9.103480e+07  1578835.179
#
#    Interbank_assets  Interbank_liabilities  ...  \
# 0       284783000.0           1.524420e+08  ...
# 1        47474000.0           5.042000e+07  ...
# 2       136395000.0           6.447600e+07  ...
# 3        39389000.0           5.633200e+07  ...
# 4       106306814.9           5.266122e+07  ...
#
#    Total_equity_/_Total_liabilities_excluding_hybrid_capital_and_subordinated_liabilities  \
# 0                                          10.936928
# 1                                          14.459611
# 2                                          12.507992
# 3                                          10.323970
# 4                                           6.550267
#
#    Capital_funds_/_Total_assets  Growth_in_gross_customer_loans_&advances  \
# 0                     10.241710                                  2.811964
# 1                     12.964140                                  0.608238
# 2                     11.812522                                  0.475133
# 3                     10.161142                                  3.519757
# 4                      6.762959                                  4.084363
#
#    Capital_funds_/_Net_loans_&_advances_to_customers  Time_deposits  \
# 0                                          27.750983   6.850800e+07
# 1                                          24.754956   6.492200e+07
# 2                                          27.814021   5.153900e+07
# 3                                          18.935299   1.020940e+08
# 4                                          13.596449   4.453125e+05
#
#    Non-interest_income_/_Operating_revenues  \
# 0                                 52.033698
# 1                                 40.143750
# 2                                 24.584387
# 3                                 38.391164
# 4                                 35.902972
#
#    Net_interest_margin_(interest_earning_assets)  rank_next_quarter  \
# 0                                       2.730287                  1
# 1                                       2.951758                  3
# 2                                       3.803368                  1
# 3                                       3.497978                  3
# 4                                       2.223331                  3
#
#    srisk_ratio  srisk_value
# 0         9.68      64677.6
# 1        11.93      79705.4
# 2          NaN          NaN
# 3         0.00      -6116.6
# 4          NaN          NaN
#
# [5 rows x 74 columns]
# === 2023 Q4 Edges ===
#    Sourceid  Targetid        Weights
# 0         0        37      32.279364
# 1         0        77  216129.869906
# 2         0        89      11.360000
# 3         0       121    1677.721600
# 4         0       185   22840.382978
# === 2023 Q4 Nodes ===
#    index  Total_assets  Total_liabilities        Equity  Liquid_assets  \
# 0      0  3.395126e+09       3.095803e+09  2.993230e+08   1.409532e+09
# 1      1  2.540116e+09       2.303910e+09  2.362060e+08   6.981110e+08
# 2      2  1.684710e+09       1.520999e+09  1.637110e+08   6.522330e+08
# 3      3  1.733244e+09       1.570242e+09  1.630020e+08   4.484550e+08
# 4      4  1.410874e+09       1.330053e+09  8.082114e+07   6.257934e+08
#
#    Deposits_and_short-term_funding  Long-term_funding   Net_income  \
# 0                     2.632982e+09        181884000.0  8609000.000
# 1                     2.185351e+09         37300000.0  4591000.000
# 2                     1.371838e+09         41969000.0  -517000.000
# 3                     1.446506e+09         69275000.0  3958000.000
# 4                     1.043950e+09        141745366.8  2080599.795
#
#    Interbank_assets  Interbank_liabilities  ...  \
# 0       335562000.0            160398000.0  ...
# 1        75968000.0            153009000.0  ...
# 2       105832000.0             81857000.0  ...
# 3        75876000.0             27760000.0  ...
# 4       218211374.4            150915578.0  ...
#
#    Profit_attributable_to_group_equity_holders  \
# 0                                  8610000.000
# 1                                  4591000.000
# 2                                  -578000.000
# 3                                  3956000.000
# 4                                  1939297.799
#
#    Interest_income_on_customer_loans_&_advances  Total_other_earning_assets  \
# 0                                   23216000.00                1.297303e+09
# 1                                   15412000.00                1.069991e+09
# 2                                   14671000.00                7.163330e+08
# 3                                   14615000.00                5.552650e+08
# 4                                    4245548.23                7.026977e+08
#
#    Total_equity_/_Total_liabilities_excluding_hybrid_capital_and_subordinated_liabilities  \
# 0                                           9.669467
# 1                                          10.258969
# 2                                          10.838206
# 3                                          10.447420
# 4                                           6.108385
#
#    Capital_funds_/_Total_assets  Growth_in_gross_customer_loans_&advances  \
# 0                      8.823767                                  1.024511
# 1                      9.357132                                  0.224028
# 2                     10.340711                                  3.492659
# 3                      9.983072                                 -0.527822
# 4                      6.220005                                  2.958175
#
#    Capital_funds_/_Net_loans_&_advances_to_customers  Time_deposits  \
# 0                                          23.245608    292404000.0
# 1                                          23.055978    152493000.0
# 2                                          27.489696    129763000.0
# 3                                          19.516286    195576000.0
# 4                                          13.325109    153735129.5
#
#    Non-interest_income_/_Operating_revenues  \
# 0                                 30.920738
# 1                                 23.218789
# 2                                 17.881500
# 3                                 27.659235
# 4                                 37.503127
#
#    Net_interest_margin_(interest_earning_assets)
# 0                                       4.438297
# 1                                       2.990640
# 2                                       3.801693
# 3                                       4.022865
# 4                                       1.880460
#
# [5 rows x 71 columns]

# %%
df_evolution = pd.DataFrame(rows).sort_values(["year", "quarter"]).reset_index(drop=True)
df_evolution["delta_edges"] = df_evolution["n_edges"].diff()

# Plot 1: Edges over time
plt.figure()
plt.plot(df_evolution["period"], df_evolution["n_edges"], marker="o")
plt.xticks(rotation=90)
plt.xlabel("Quarter")
plt.ylabel("Number of edges")
plt.title("Evolution of connections by quarter")
plt.tight_layout()
plt.show()

# %%
# for loop to have the basic stats of each quarter and concatenate them into a single DataFrame
stats_rows = []

for year in range(2016, 2024):
    for q in range(1, 5):
        n = globals()[f"nodes_{year}_Q{q}"]

        # select only numeric financial features
        num_cols = n.select_dtypes(include="number").drop(columns=["index"], errors="ignore")

        # describe for this quarter
        desc = num_cols.describe().T.reset_index()
        desc = desc.rename(columns={"index": "feature"})

        # add time information
        desc["year"] = year
        desc["quarter"] = q
        desc["period"] = f"{year} Q{q}"
        desc["n_banks"] = len(n)

        stats_rows.append(desc)

# concatenating the stats into a single dataframe
df_node_stats = pd.concat(stats_rows, ignore_index=True)

display(df_node_stats.head(-5))
print(df_node_stats.shape)
# Out:
#                                                 feature   count          mean  \
# 0                                          Total_assets  4548.0  6.335496e+06
# 1                                     Total_liabilities  4548.0  5.751365e+06
# 2                                                Equity  4548.0  5.764525e+05
# 3                                         Liquid_assets  4548.0  2.023994e+06
# 4                       Deposits_and_short-term_funding  4548.0  4.543275e+06
# ...                                                 ...     ...           ...
# 2319        Profit_attributable_to_group_equity_holders  4548.0  2.246488e+04
# 2320       Interest_income_on_customer_loans_&_advances  4548.0  9.622044e+04
# 2321                         Total_other_earning_assets  4548.0  3.333167e+06
# 2322  Total_equity_/_Total_liabilities_excluding_hyb...  4548.0  1.296195e+02
# 2323                       Capital_funds_/_Total_assets  4548.0  1.123332e+01
#
#                std           min           25%            50%            75%  \
# 0     6.155170e+07  0.000000e+00  93289.250000  192646.500000  469170.000000
# 1     5.591334e+07  0.000000e+00  81317.500000  169584.500000  417608.750000
# 2     5.883081e+06  0.000000e+00  10731.500000   22106.000000   54308.750000
# 3     2.490484e+07  0.000000e+00  23622.500000   52625.000000  125288.750000
# 4     4.537772e+07  0.000000e+00  79113.500000  164682.000000  405300.500000
# ...            ...           ...           ...            ...            ...
# 2319  2.245993e+05 -4.938000e+06    183.000000     686.500000    2138.000000
# 2320  7.802511e+05 -1.355200e+04   1200.750000    3110.000000    8892.750000
# 2321  3.601813e+07  0.000000e+00  41415.500000   92060.500000  233455.250000
# 2322  4.849337e+03 -4.296288e+00      8.565743      10.552866      13.464668
# 2323  9.570903e+00 -4.489155e+00      7.909093       9.569500      11.921628
#
#                max  year  quarter   period  n_banks
# 0     2.015718e+09  2016        1  2016 Q1     4548
# 1     1.817839e+09  2016        1  2016 Q1     4548
# 2     2.081500e+08  2016        1  2016 Q1     4548
# 3     9.954590e+08  2016        1  2016 Q1     4548
# 4     1.532137e+09  2016        1  2016 Q1     4548
# ...            ...   ...      ...      ...      ...
# 2319  8.610000e+06  2023        4  2023 Q4     4548
# 2320  2.321600e+07  2023        4  2023 Q4     4548
# 2321  1.297303e+09  2023        4  2023 Q4     4548
# 2322  3.040000e+05  2023        4  2023 Q4     4548
# 2323  1.000000e+02  2023        4  2023 Q4     4548
#
# [2324 rows x 13 columns]
# (2329, 13)

# %%
def gini(x: pd.Series) -> float:
    x = x.dropna().astype(float).values
    if x.size == 0:
        return np.nan
    x = np.sort(x)
    if np.all(x == 0):
        return 0.0
    n = x.size
    cum = np.cumsum(x)
    return (n + 1 - 2 * np.sum(cum) / cum[-1]) / n

def summarize_metric(df: pd.DataFrame, col: str) -> dict:
    s = df[col].astype(float)
    return {
        f"{col}_mean": s.mean(),
        f"{col}_median": s.median(),
        f"{col}_p95": s.quantile(0.95),
        f"{col}_max": s.max(),
        f"{col}_gini": gini(s),
    }

quarter_summary_rows = []

for year in range(2016, 2024):
    for q in range(1, 5):
        edges = globals()[f"edges_{year}_Q{q}"]
        nodes = globals()[f"nodes_{year}_Q{q}"]

        deg_df  = degree_centrality(edges, nodes)
        bet_df  = betweenness_centrality(edges, nodes)
        clo_df  = closeness_centrality(edges, nodes)
        wdeg_df = weighted_degree(edges, nodes)
        pr_df   = pagerank_centrality(edges, nodes, reverse=True)
        dr_df   = debtrank(edges, nodes)

        features = nodes.copy().rename(columns={"index": "bank_id"})
        for df in (deg_df, bet_df, clo_df, wdeg_df, pr_df, dr_df):
            features = features.merge(df, on="bank_id", how="left")

        features["year"] = year
        features["quarter"] = q

        out_path = OUT_FEATURES / f"classical_features_{year}Q{q}.parquet"
        features.to_parquet(out_path, index=False)

        row = {
            "year": year,
            "quarter": q,
            "period": f"{year} Q{q}",
            "n_banks": len(nodes),
            "n_edges": len(edges),
            "saved_file": out_path.name,
        }

        for col, df_ref in [
            ("degree_centrality_total", deg_df),
            ("weighted_degree_total",   wdeg_df),
            ("betweenness_centrality",  bet_df),
            ("closeness_centrality",    clo_df),
            ("pagerank",                pr_df),
            ("debtrank",                dr_df),
        ]:
            row.update(summarize_metric(df_ref, col))

        quarter_summary_rows.append(row)
        print(f"[OK] {year}Q{q} | saved {out_path.name}")

df_network_descriptive = (
    pd.DataFrame(quarter_summary_rows)
      .sort_values(["year", "quarter"])
      .reset_index(drop=True)
)
# Out:
# [OK] 2016Q1 | saved classical_features_2016Q1.parquet
# [OK] 2016Q2 | saved classical_features_2016Q2.parquet
# [OK] 2016Q3 | saved classical_features_2016Q3.parquet
# [OK] 2016Q4 | saved classical_features_2016Q4.parquet
# [OK] 2017Q1 | saved classical_features_2017Q1.parquet
# [OK] 2017Q2 | saved classical_features_2017Q2.parquet
# [OK] 2017Q3 | saved classical_features_2017Q3.parquet
# [OK] 2017Q4 | saved classical_features_2017Q4.parquet
# [OK] 2018Q1 | saved classical_features_2018Q1.parquet
# [OK] 2018Q2 | saved classical_features_2018Q2.parquet
# [OK] 2018Q3 | saved classical_features_2018Q3.parquet
# [OK] 2018Q4 | saved classical_features_2018Q4.parquet
# [OK] 2019Q1 | saved classical_features_2019Q1.parquet
# [OK] 2019Q2 | saved classical_features_2019Q2.parquet
# [OK] 2019Q3 | saved classical_features_2019Q3.parquet
# [OK] 2019Q4 | saved classical_features_2019Q4.parquet
# [OK] 2020Q1 | saved classical_features_2020Q1.parquet
# [OK] 2020Q2 | saved classical_features_2020Q2.parquet
# [OK] 2020Q3 | saved classical_features_2020Q3.parquet
# [OK] 2020Q4 | saved classical_features_2020Q4.parquet
# [OK] 2021Q1 | saved classical_features_2021Q1.parquet
# [OK] 2021Q2 | saved classical_features_2021Q2.parquet
# [OK] 2021Q3 | saved classical_features_2021Q3.parquet
# [OK] 2021Q4 | saved classical_features_2021Q4.parquet
# [OK] 2022Q1 | saved classical_features_2022Q1.parquet
# [OK] 2022Q2 | saved classical_features_2022Q2.parquet
# [OK] 2022Q3 | saved classical_features_2022Q3.parquet
# [OK] 2022Q4 | saved classical_features_2022Q4.parquet
# [OK] 2023Q1 | saved classical_features_2023Q1.parquet
# [OK] 2023Q2 | saved classical_features_2023Q2.parquet
# [OK] 2023Q3 | saved classical_features_2023Q3.parquet
# [OK] 2023Q4 | saved classical_features_2023Q4.parquet

# %%
# Eigenvector centrality — computed separately because it may fail to converge
# on some quarters. Loaded and patched into the existing parquets.

for year in range(2016, 2024):
    for q in range(1, 5):
        edges = globals()[f"edges_{year}_Q{q}"]
        nodes = globals()[f"nodes_{year}_Q{q}"]

        eig_df = eigenvector_centrality(edges, nodes)

        out_path = OUT_FEATURES / f"classical_features_{year}Q{q}.parquet"
        features = pd.read_parquet(out_path)
        features = features.merge(eig_df, on="bank_id", how="left")
        features.to_parquet(out_path, index=False)

        print(f"[OK] {year}Q{q} | added eigenvector_centrality")
# Out:
# [OK] 2016Q1 | added eigenvector_centrality
# [OK] 2016Q2 | added eigenvector_centrality
# [OK] 2016Q3 | added eigenvector_centrality
# [OK] 2016Q4 | added eigenvector_centrality
# [OK] 2017Q1 | added eigenvector_centrality
# [OK] 2017Q2 | added eigenvector_centrality
# [OK] 2017Q3 | added eigenvector_centrality
# [OK] 2017Q4 | added eigenvector_centrality
# [OK] 2018Q1 | added eigenvector_centrality
# [OK] 2018Q2 | added eigenvector_centrality
# [OK] 2018Q3 | added eigenvector_centrality
# [OK] 2018Q4 | added eigenvector_centrality
# [OK] 2019Q1 | added eigenvector_centrality
# [OK] 2019Q2 | added eigenvector_centrality
# [OK] 2019Q3 | added eigenvector_centrality
# [OK] 2019Q4 | added eigenvector_centrality
# [OK] 2020Q1 | added eigenvector_centrality
# [OK] 2020Q2 | added eigenvector_centrality
# [OK] 2020Q3 | added eigenvector_centrality
# [OK] 2020Q4 | added eigenvector_centrality
# [OK] 2021Q1 | added eigenvector_centrality
# [OK] 2021Q2 | added eigenvector_centrality
# [OK] 2021Q3 | added eigenvector_centrality
# [OK] 2021Q4 | added eigenvector_centrality
# [OK] 2022Q1 | added eigenvector_centrality
# [OK] 2022Q2 | added eigenvector_centrality
# [OK] 2022Q3 | added eigenvector_centrality
# [OK] 2022Q4 | added eigenvector_centrality
# [OK] 2023Q1 | added eigenvector_centrality
# [OK] 2023Q2 | added eigenvector_centrality
# [OK] 2023Q3 | added eigenvector_centrality
# [OK] 2023Q4 | added eigenvector_centrality

# %%
df_2016_q1 = pd.read_parquet(OUT_FEATURES / "classical_features_2016Q1.parquet")

display(df_2016_q1.head())
print(df_2016_q1.shape)
# Out:
#    bank_id  Total_assets  Total_liabilities        Equity  Liquid_assets  \
# 0        0  2.015718e+09       1.817839e+09  1.978790e+08    995459000.0
# 1        1  1.653947e+09       1.445797e+09  2.081500e+08    520240000.0
# 2        2  1.342643e+09       1.194543e+09  1.481000e+08    584455000.0
# 3        3  1.667785e+09       1.513099e+09  1.546860e+08    555658000.0
# 4        4  8.335113e+08       7.826065e+08  5.090483e+07    313991467.7
#
#    Deposits_and_short-term_funding  Long-term_funding   Net_income  \
# 0                     1.532137e+09       9.085800e+07  4197000.000
# 1                     1.363841e+09       2.511900e+07  3712000.000
# 2                     1.009545e+09       6.186300e+07  2879000.000
# 3                     1.334370e+09       1.225960e+08  4735000.000
# 4                     5.811292e+08       9.103480e+07  1578835.179
#
#    Interbank_assets  Interbank_liabilities  ...  betweenness_centrality  \
# 0       284783000.0           1.524420e+08  ...                0.168029
# 1        47474000.0           5.042000e+07  ...                0.023721
# 2       136395000.0           6.447600e+07  ...                0.080558
# 3        39389000.0           5.633200e+07  ...                0.075254
# 4       106306814.9           5.266122e+07  ...                0.018652
#
#    closeness_centrality  weighted_degree_in  weighted_degree_out  \
# 0              0.539087        1.524420e+08         1.888844e+08
# 1              0.481475        5.042000e+07         4.747400e+07
# 2              0.494289        6.447600e+07         7.978602e+07
# 3              0.492850        5.633200e+07         2.417689e+07
# 4              0.476369        5.266122e+07         9.502730e+07
#
#    weighted_degree_total  pagerank  debtrank  year  quarter  \
# 0           3.413264e+08  0.065960  0.697748  2016        1
# 1           9.789400e+07  0.014796  0.721792  2016        1
# 2           1.442620e+08  0.021753  0.733434  2016        1
# 3           8.050889e+07  0.008971  0.702749  2016        1
# 4           1.476885e+08  0.029540  0.770690  2016        1
#
#    eigenvector_centrality
# 0                0.540908
# 1                0.116720
# 2                0.051427
# 3                0.058684
# 4                0.004115
#
# [5 rows x 87 columns]
# (4548, 87)

# %%
df_2016_q1["debtrank"].describe()
# Out:
# count    4548.000000
# mean        0.230950
# std         0.357971
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.781057
# max         0.805948
# Name: debtrank, dtype: float64
